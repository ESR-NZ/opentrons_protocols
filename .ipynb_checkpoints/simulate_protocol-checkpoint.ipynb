# %%
#import sys
#!{sys.executable} -m pip install --user opentrons
from opentrons.simulate import simulate, format_runlog
# read the file
protocol_file = open('normalisation.py')
# simulate() the protocol, keeping the runlog
runlog, _bundle = simulate(protocol_file)
# print the runlog
print(format_runlog(runlog))
# Out:
# /home/mstorey/.opentrons/deck_calibration.json not found. Loading defaults
# /home/mstorey/.opentrons/robot_settings.json not found. Loading defaults
# Loading json containers...
# Json container file load complete, listing database
# Found 0 containers to add. Starting migration...
# Database migration complete!
# Input file created: Fri May  8 11:21:36 2020
# Distributing [97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8] from A1 of USA Scientific 12 Well Reservoir 22 mL on 11 to A5 of Corning 96 Well Plate 360 µL Flat on Temperature Module on 10
# 	Transferring [97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8, 97.8] from A1 of USA Scientific 12 Well Reservoir 22 mL on 11 to A5 of Corning 96 Well Plate 360 µL Flat on Temperature Module on 10
# ...
